# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:85% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:16pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:85% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:16pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# <font size="6" color="red">ch01. 파이썬 개요 및 환경 설정</font>
# # 1. 마크다운이란?
# - 코드와 함께 문서화 할 수 있음
# - 다양한 문서화 문법 ex.README.md
# # 2. 주피터 노트북 실행법
# - shift+Enter : 포커스된 셀이 실행되고 커서가 다음셀로 이동
# - alt+Enter : 포커스된 셀이 실행되고 다음셀이 생성된 후 다음셀로 이동
# - ctrl+Enter : 포커스된 셀이 실행되고 포커스 이동이 없음
# - Enter : 다시 편집 상태로

# %%
# 주석(실행 안 됨)
# 셀 하나하나에 파이썬 실행 소스를 입력

# %%
# print() 함수를 이용해서 출력
print('Hello World\n\n\n\n홍길동')
print(1)
# Out:
# Hello World
#
#
#
# 홍길동
# 1

# %%
age =25
duration ="2"
print(str(age)+duration)
print(age+int(duration))
#view > toggle line Number 선택
# Out:
# 252
# 27

# %%
age
# Out:
# 25

# %% [markdown]
# # 3. ESC키 누르고(핫키)
# - dd: 셀삭제
# - b : 아랫셀 추가
# - a : 윗셀 추가
# - m : 마크다운 셀
# - y : 코드셀(소스셀)로 변경
# - o : 실행 결과 접기/펴기(토글)

# %%
#주피터 노트북에서 cmd 명령어
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: A014-DCD6
#
#  C:\ai\source\01_python 디렉터리
#
# 2026-06-23  오전 11:37    <DIR>          .
# 2026-06-23  오전 10:19    <DIR>          ..
# 2026-06-23  오전 10:55    <DIR>          .ipynb_checkpoints
# 2026-06-23  오전 11:37             5,382 ch01_파이썬개요 및 환경설정.ipynb
# 2026-06-23  오전 10:46             2,724 Untitled.ipynb
#                2개 파일               8,106 바이트
#                3개 디렉터리  170,796,814,336 바이트 남음

# %%
#매직 명령어(주피터노트북 자체 명령어)
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: A014-DCD6
#
#  C:\ai\source\01_python 디렉터리
#
# 2026-06-23  오전 11:39    <DIR>          .
# 2026-06-23  오전 10:19    <DIR>          ..
# 2026-06-23  오전 10:55    <DIR>          .ipynb_checkpoints
# 2026-06-23  오전 11:39             6,308 ch01_파이썬개요 및 환경설정.ipynb
# 2026-06-23  오전 10:46             2,724 Untitled.ipynb
#                2개 파일               9,032 바이트
#                3개 디렉터리  170,796,371,968 바이트 남음
