# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:85% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:16pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:85% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:16pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %config InlineBackend.figure_format = "retina"
# 한글설정
plt.rc('font', family='Malgun Gothic') # 윈도우즈
plt.rc('axes', unicode_minus=False) # 축의 - 깨짐 방지

# %%
df_first=pd.read_csv('c:/ai/downloads/shareData/분양가격/전국 평균 평당 분양가격(2013년 9월부터 2015년 8월까지).csv',encoding='cp949')
df_first.head()
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
# 1  부산      8111     8111     9078     8965     9402     9501     9453
# 2  대구      8080     8080     8077     8101     8267     8274     8360
# 3  인천     10204    10204    10408    10408    10000     9844    10058
# 4  광주      6098     7326     7611     7346     7346     7523     7659
#
#    2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 0    18742    19274  ...     20242     20269    20670    20670    19415
# 1     9457     9411  ...      9208      9208     9204     9235     9279
# 2     8360     8370  ...      8439      8253     8327     8416     8441
# 3     9974     9973  ...     10020     10020    10017     9876     9876
# 4     7612     7622  ...      7752      7748     7752     7756     7861
#
#    2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    18842    18367    18374    18152    18443
# ...

# %%
pd.options.display.max_columns=22

# %%
df_first.head()
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
# 1  부산      8111     8111     9078     8965     9402     9501     9453
# 2  대구      8080     8080     8077     8101     8267     8274     8360
# 3  인천     10204    10204    10408    10408    10000     9844    10058
# 4  광주      6098     7326     7611     7346     7346     7523     7659
#
#    2014년7월  2014년8월  2014년9월  2014년10월  2014년11월  2014년12월  2015년1월  2015년2월  \
# 0    18742    19274    19404     19759     20242     20269    20670    20670
# 1     9457     9411     9258      9110      9208      9208     9204     9235
# 2     8360     8370     8449      8403      8439      8253     8327     8416
# 3     9974     9973     9973     10016     10020     10020    10017     9876
# 4     7612     7622     7802      7707      7752      7748     7752     7756
#
#    2015년3월  2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# ...

# %%
df_first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        17 non-null     object
#  1   2013년12월  17 non-null     int64
#  2   2014년1월   17 non-null     int64
#  3   2014년2월   17 non-null     int64
#  4   2014년3월   17 non-null     int64
#  5   2014년4월   17 non-null     int64
#  6   2014년5월   17 non-null     int64
#  7   2014년6월   17 non-null     int64
#  8   2014년7월   17 non-null     int64
#  9   2014년8월   17 non-null     int64
#  10  2014년9월   17 non-null     int64
#  11  2014년10월  17 non-null     int64
#  12  2014년11월  17 non-null     int64
#  13  2014년12월  17 non-null     int64
#  14  2015년1월   17 non-null     int64
#  15  2015년2월   17 non-null     int64
#  16  2015년3월   17 non-null     int64
#  17  2015년4월   17 non-null     int64
#  18  2015년5월   17 non-null     int64
#  19  2015년6월   17 non-null     int64
# ...

# %%
df_first.head()
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
# 1  부산      8111     8111     9078     8965     9402     9501     9453
# 2  대구      8080     8080     8077     8101     8267     8274     8360
# 3  인천     10204    10204    10408    10408    10000     9844    10058
# 4  광주      6098     7326     7611     7346     7346     7523     7659
#
#    2014년7월  2014년8월  2014년9월  2014년10월  2014년11월  2014년12월  2015년1월  2015년2월  \
# 0    18742    19274    19404     19759     20242     20269    20670    20670
# 1     9457     9411     9258      9110      9208      9208     9204     9235
# 2     8360     8370     8449      8403      8439      8253     8327     8416
# 3     9974     9973     9973     10016     10020     10020    10017     9876
# 4     7612     7622     7802      7707      7752      7748     7752     7756
#
#    2015년3월  2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# ...

# %%
df_first.set_index('지역',inplace=True)

# %%
df_first.head()
# Out:
#     2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  2014년7월  \
# 지역
# 서울     18189    17925    17925    18016    18098    19446    18867    18742
# 부산      8111     8111     9078     8965     9402     9501     9453     9457
# 대구      8080     8080     8077     8101     8267     8274     8360     8360
# 인천     10204    10204    10408    10408    10000     9844    10058     9974
# 광주      6098     7326     7611     7346     7346     7523     7659     7612
#
#     2014년8월  2014년9월  2014년10월  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 지역
# 서울    19274    19404     19759     20242     20269    20670    20670    19415
# 부산     9411     9258      9110      9208      9208     9204     9235     9279
# 대구     8370     8449      8403      8439      8253     8327     8416     8441
# 인천     9973     9973     10016     10020     10020    10017     9876     9876
# 광주     7622     7802      7707      7752      7748     7752     7756     7861
#
# ...

# %%
df_first.reset_index(inplace=True)

# %%
df_first
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0   서울     18189    17925    17925    18016    18098    19446    18867
# 1   부산      8111     8111     9078     8965     9402     9501     9453
# 2   대구      8080     8080     8077     8101     8267     8274     8360
# 3   인천     10204    10204    10408    10408    10000     9844    10058
# 4   광주      6098     7326     7611     7346     7346     7523     7659
# 5   대전      8321     8321     8321     8341     8341     8341     8333
# 6   울산      8090     8090     8090     8153     8153     8153     8153
# 7   경기     10855    10855    10791    10784    10876    10646    10266
# 8   세종      7601     7600     7532     7814     7908     7934     8067
# 9   강원      6230     6230     6230     6141     6373     6350     6350
# 10  충북      6589     6589     6611     6625     6678     6598     6587
# 11  충남      6365     6365     6379     6287     6552     6591     6644
# ...

# %%
plt.figure(figsize=(25,5))
sns.heatmap(df_first,annot=True,fmt='d',cmap='Greens',cbar=False)
# Out:
# <Axes: ylabel='지역'>

# %%
df_last=pd.read_csv('c:/ai/downloads/shareData/분양가격/주택도시보증공사_전국 신규 민간아파트 분양가격 동향_20260531 (3).csv',encoding='cp949')
df_last.tail()
# Out:
#       지역명                     규모구분    연도  월 분양가격(제곱미터당 천원)
# 10875  제주                     모든면적  2026  5           4473
# 10876  제주            전용면적 60제곱미터이하  2026  5            NaN
# 10877  제주   전용면적 60제곱미터초과 85제곱미터이하  2026  5           4485
# 10878  제주  전용면적 85제곱미터초과 102제곱미터이하  2026  5            NaN
# 10879  제주           전용면적 102제곱미터초과  2026  5           4350

# %%
df_last['분양가격(제곱미터당 천원)'].describe(include=all)
# Out:
# count     10035
# unique     3637
# top
# freq         95
# Name: 분양가격(제곱미터당 천원), dtype: object

# %%
float('2323'),float(np.nan)
# Out:
# (2323.0, nan)

# %%
df_last.isna().sum()
# Out:
# 지역명                 0
# 규모구분                0
# 연도                  0
# 월                   0
# 분양가격(제곱미터당 천원)    845
# dtype: int64

# %%
pd.to_numeric(df_last['분양가격(제곱미터당 천원)'],errors='coerce').isna().sum()

# %%
temp=pd.to_numeric(df_last['분양가격(제곱미터당 천원)'],errors='coerce')
nanidx=temp[temp.isna()].index
nanidx
# Out:
# Int64Index([   28,    29,    34,    81,   113,   114,   119,   166,   198,
#               199,
#             ...
#             10793, 10816, 10818, 10823, 10838, 10839, 10858, 10863, 10876,
#             10878],
#            dtype='int64', length=973)

# %%
df_last.isna().sum()
# Out:
# 지역명                 0
# 규모구분                0
# 연도                  0
# 월                   0
# 분양가격(제곱미터당 천원)    845
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 nanidx.info()
#
# AttributeError: 'Int64Index' object has no attribute 'info'

# %%
# 973-845 갯수가 결측치가 아닌 엉뚱한 데이터  ㅇ(-, ' ' 등등)

# %%
import matplotlib.pyplot as plt
# from matplotlib import pyplot as plt
import matplotlib
matplotlib.__version__
# 시각화한 그래프를 저장할 해상도 높이기
# %config InlineBackend.figure_format='retina'

# 한글 설정(Window / MacOS)
plt.rc('font',family='Malgun Gothic') #윈도우즈
#plt.rc('font',family='Apple Gothic') #MacOS
plt.rc('axes',unicode_minus=False) #축의 (-)깨짐 방지


# warning(경고)  안보이게
import warnings
#warnings.filterwarnings(action='default')  # 기본 경고 메세지 다 보이게
#warnings.filterwarnings(action='ignore') # 경고메세지 안보이게
import seaborn as sns

# %%
import numpy as np

# %%
plt.figure(figsize=(10,5))
plt.rcParams['figure.figsize']=(5,5)
plt.subplot(2,1,)

# %%
fig, axes = plt.subplots(nrows=2,ncols=2,sharex=False,sharey=False, figsize=(7,4) )
axes[0,0].plot(x,np.sin(x),c='#3ecdf3',lw=9) # color는 상기 url 참조   linewidth=9
axes[0,1].plot(x,np.cos(x), 'b:') #color='b', linestyle='--' (데시라인), : (점선)
axes[1,0].plot(x,np.tanh(x), '#6b3ef3')
axes[1,0].plot([0,2,4],[-1,0,1], 'ko-.') #color='black', marker='o', linestyle='-.'
axes[1,1].plot(x,np.sin(x)*np.cos(x), 'r--')
plt.show()

# %%
axes[0,0].plot(x,np.sin(x),c='#3ecdf3',lw=9)

# %%
plt.plot()

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 9             4.9          3.1           1.5          0.1      setosa
# 71            6.1          2.8           4.0          1.3  versicolor
# 119           6.0          2.2           5.0          1.5   virginica
# 89            5.5          2.5           4.0          1.3  versicolor
# 118           7.7          2.6           6.9          2.3   virginica

# %%
iris.plot(kind='line',xlim=(0,200),ylim=(0,10),)
# Out:
# <Axes: >

# %%
df.plot -(x=None,y=None, kind='line',figsize=None, title=None, grid=None, xlim, ylim...)

# %%
iris.plot(x='species',kind='bar')
# Out:
# <Axes: xlabel='species'>

# %%
iris.index.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 iris.index.info()
#
# AttributeError: 'RangeIndex' object has no attribute 'info'

# %%
iris.plot(kind='box',)
# Out:
# <Axes: >

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.rcParams['figure.figsize']=(10,5)
plt.violinplot(iris.petal_length)
plt.hist()
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2297dc8fd30>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2297ccdba90>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2297dceb3d0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2297dceb730>}

# %%
x=np.linspace(0,10)
y=np.cos(x)
plt.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
sns.stripplot(data=iris, x='species',y='petal_length',
             order=['versicolor','virginica','setosa'],
             hue='species')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
import os
import requests
import json
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
client_id = os.getenv('NEW_CLIENT_ID')
client_secret = os.getenv('NEW_CLIENT_SECRET')
encText="카카오톡"
url = f"https://naverapihub.apigw.ntruss.com/search/v1/kin"
params = {'query': encText, 'display': 20}
headers = {
    'X-NCP-APIGW-API-KEY-ID': client_id,
    'X-NCP-APIGW-API-KEY':client_secret
}
response =requests.get(url,params=params, headers=headers)
items =response.json()['items']
items_list=[]
for item in items:
    title=item['title'].replace('<b>','').replace('</b>','')
    link=item['link']
    description=item['description'].replace('<b>','').replace('</b>','')
    items_list.append([title, link, description])
pd.DataFrame(items_list, columns=['title','link','description']).sample()
# Out:
#          title                                               link  \
# 7  카카오톡 로그인 오류  https://kin.naver.com/qna/detail.naver?dirId=1...
#
#                                          description
# 7  카카오톡 웹사이트에서는 아이디 비번 로그인 아주잘됩니다. 그런데 어플 카카오톡 에서...
